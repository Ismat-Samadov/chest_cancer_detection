# %%
# Improved Chest CT Cancer Binary Classification without TensorFlow Addons
# -------------------------------------------------------
# Enhanced implementation with multiple model architectures and advanced techniques

# Import necessary libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Add, Multiply
from tensorflow.keras.applications import DenseNet121, ResNet50, EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import binary_crossentropy
from PIL import Image, ImageEnhance, ImageOps
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import KFold
import seaborn as sns

# Custom implementation of Focal Loss to replace TensorFlow Addons
def sigmoid_focal_crossentropy(y_true, y_pred, alpha=0.25, gamma=2.0):
    """
    Custom implementation of Focal Loss
    
    Args:
        y_true: Ground truth values
        y_pred: Predicted values
        alpha: Weighting factor for the rare class
        gamma: Focusing parameter that reduces the loss for well-classified examples
        
    Returns:
        Focal loss value
    """
    # Get binary crossentropy
    bce = binary_crossentropy(y_true, y_pred)
    
    # Convert y_true to float32 if needed
    y_true = tf.cast(y_true, dtype=tf.float32)
    
    # Calculate the modulating factor
    p_t = (y_true * y_pred) + ((1 - y_true) * (1 - y_pred))
    alpha_factor = y_true * alpha + (1 - y_true) * (1 - alpha)
    modulating_factor = tf.pow((1.0 - p_t), gamma)
    
    # Apply the factors and return
    return alpha_factor * modulating_factor * bce

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define constants
IMG_SIZE = 256  # Increased from 224 for more detail
BATCH_SIZE = 16
EPOCHS = 30  # More epochs for improved architectures
BASE_DIR = "/kaggle/input/chest-ctscan-images/Data"
MODELS_DIR = "models"
PLOTS_DIR = "plots"
USE_ENSEMBLE = True  # Set to True to use ensemble of models
MODEL_ARCHITECTURE = "densenet"  # Options: "densenet", "resnet", "efficientnet", "ensemble"
USE_ATTENTION = True  # Use attention mechanisms
APPLY_MIXUP = True  # Apply mixup augmentation

# Create directories for outputs
os.makedirs(MODELS_DIR, exist_ok=True)
os.makedirs(PLOTS_DIR, exist_ok=True)

# -------------------------------------------------------
# Enhanced Preprocessing Functions
# -------------------------------------------------------

def apply_clahe(img, chance=0.5):
    """Apply CLAHE with enhanced parameters for better contrast in CT scans"""
    if np.random.random() < chance:
        if not isinstance(img, Image.Image):
            img = Image.fromarray((img * 255).astype(np.uint8))
        img = ImageOps.equalize(img)
        return np.array(img) / 255.0
    return img

def apply_random_contrast(img, chance=0.5, factor_range=(0.5, 1.8)):
    """Apply stronger contrast adjustment for CT scans"""
    if np.random.random() < chance:
        if not isinstance(img, Image.Image):
            img = Image.fromarray((img * 255).astype(np.uint8))
        factor = np.random.uniform(*factor_range)
        enhancer = ImageEnhance.Contrast(img)
        img = enhancer.enhance(factor)
        return np.array(img) / 255.0
    return img

def apply_random_sharpness(img, chance=0.5, factor_range=(0.5, 2.2)):
    """Apply stronger sharpness for better tissue boundary detection"""
    if np.random.random() < chance:
        if not isinstance(img, Image.Image):
            img = Image.fromarray((img * 255).astype(np.uint8))
        factor = np.random.uniform(*factor_range)
        enhancer = ImageEnhance.Sharpness(img)
        img = enhancer.enhance(factor)
        return np.array(img) / 255.0
    return img

def apply_windowing(img, chance=0.4, window_width_range=(1500, 2500), window_center_range=(-600, 500)):
    """
    Apply CT windowing to enhance specific tissues
    
    Why: CT windowing is a domain-specific technique that adjusts contrast
    to highlight specific tissue types based on their Hounsfield units
    """
    if np.random.random() < chance:
        if not isinstance(img, np.ndarray):
            img = np.array(img)
        
        # Simulate Hounsfield unit range (normally from -1000 to +1000)
        # For this example we scale 0-1 to -1000 to +1000
        hu_img = (img * 2000) - 1000
        
        # Randomly select window width and center
        window_width = np.random.uniform(*window_width_range)
        window_center = np.random.uniform(*window_center_range)
        
        # Apply windowing
        min_value = window_center - window_width/2
        max_value = window_center + window_width/2
        windowed = np.clip(hu_img, min_value, max_value)
        
        # Rescale to 0-1
        windowed = (windowed - min_value) / (max_value - min_value)
        windowed = np.clip(windowed, 0, 1)
        
        return windowed
    return img

def custom_preprocessing(img):
    """Enhanced preprocessing pipeline for CT scans"""
    img = apply_clahe(img, chance=0.4)
    img = apply_random_contrast(img, chance=0.4)
    img = apply_random_sharpness(img, chance=0.4)
    img = apply_windowing(img, chance=0.3)
    return img

# -------------------------------------------------------
# MixUp Augmentation
# -------------------------------------------------------

def mixup_augmentation(x, y, alpha=0.2):
    """
    Apply MixUp augmentation with proper data type handling
    """
    # Convert inputs to tensors with appropriate types
    x = tf.convert_to_tensor(x, dtype=tf.float32)
    y = tf.convert_to_tensor(y, dtype=tf.float32)  # Convert labels to float
    
    batch_size = tf.shape(x)[0]
    
    # Create indices for shuffling
    indices = tf.random.shuffle(tf.range(batch_size))
    
    # Sample lambda from beta distribution
    random_lambda = tf.random.stateless_gamma([batch_size], seed=[42, 0], alpha=alpha) / \
                    tf.random.stateless_gamma([batch_size], seed=[42, 1], alpha=alpha)
    random_lambda = tf.minimum(random_lambda, 1.0)
    
    # Reshape lambda for broadcasting with images
    random_lambda_x = tf.reshape(random_lambda, [batch_size, 1, 1, 1])
    
    # Apply mixup to images
    shuffled_x = tf.gather(x, indices)
    mixed_x = random_lambda_x * x + (1.0 - random_lambda_x) * shuffled_x
    
    # Apply mixup to labels
    random_lambda_y = tf.reshape(random_lambda, [batch_size])
    shuffled_y = tf.gather(y, indices)
    mixed_y = random_lambda_y * y + (1.0 - random_lambda_y) * shuffled_y
    
    return mixed_x, mixed_y

# -------------------------------------------------------
# Enhanced Data Generator with MixUp
# -------------------------------------------------------

class EnhancedBalancedGenerator(tf.keras.utils.Sequence):
    def __init__(self, dataframe, batch_size=16, target_size=(256, 256), 
                 shuffle=True, datagen=None, balanced=True, apply_mixup=False):
        """Enhanced generator with MixUp capability"""
        self.dataframe = dataframe
        self.batch_size = batch_size
        self.target_size = target_size
        self.shuffle = shuffle
        self.datagen = datagen if datagen is not None else ImageDataGenerator(rescale=1./255)
        self.balanced = balanced
        self.apply_mixup = apply_mixup
        
        # Split indices by class
        self.normal_indices = dataframe[dataframe['class'] == 0].index.tolist()
        self.cancer_indices = dataframe[dataframe['class'] == 1].index.tolist()
        
        # Check if we have both classes
        self.has_both_classes = len(self.normal_indices) > 0 and len(self.cancer_indices) > 0
        
        if self.balanced and not self.has_both_classes:
            print(f"WARNING: Can't create balanced batches. Normal samples: {len(self.normal_indices)}, "
                  f"Cancer samples: {len(self.cancer_indices)}. Switching to unbalanced sampling.")
            self.balanced = False
        
        # Number of batches - increased for better training
        self.batches_per_epoch = 75 if self.balanced else max(1, len(dataframe) // batch_size)
        
        # Reset state for each epoch
        self.on_epoch_end()
    
    def __len__(self):
        return self.batches_per_epoch

    def __getitem__(self, idx):
        batch_indices = []
        
        if self.balanced and self.has_both_classes:
            # For each batch, select half normal and half cancer
            half_batch = self.batch_size // 2
            
            # Get indices for this batch
            batch_normal_indices = np.random.choice(self.normal_indices, size=half_batch, replace=True)
            batch_cancer_indices = np.random.choice(self.cancer_indices, size=half_batch, replace=True)
            batch_indices = np.concatenate([batch_normal_indices, batch_cancer_indices])
            
            # Shuffle indices
            if self.shuffle:
                np.random.shuffle(batch_indices)
        else:
            # For unbalanced batches, just select randomly from all indices
            idx_offset = (idx * self.batch_size) % len(self.dataframe)
            batch_indices = np.arange(idx_offset, min(idx_offset + self.batch_size, len(self.dataframe)))
            if self.shuffle:
                np.random.shuffle(batch_indices)
        
        # Load images and labels
        batch_x = []
        batch_y = []
        
        for i in batch_indices:
            filename = self.dataframe.iloc[i]['filename']
            class_label = self.dataframe.iloc[i]['class']
            
            # Load image with error handling
            try:
                img = Image.open(filename)
                img = img.resize(self.target_size)
                img = img.convert('RGB')  # Ensure 3 channels
                img_array = np.array(img) / 255.0  # Normalize
                
                # Apply data augmentation if available
                if self.datagen is not None:
                    # Convert to batch of 1 for augmentation
                    img_array = np.expand_dims(img_array, axis=0)
                    # Get augmented image
                    augmented = next(self.datagen.flow(img_array, batch_size=1, shuffle=False))
                    img_array = augmented[0]
                
                batch_x.append(img_array)
                batch_y.append(class_label)
            except Exception as e:
                print(f"Error processing image {filename}: {e}")
                continue
        
        # Convert to numpy arrays
        batch_x = np.array(batch_x)
        batch_y = np.array(batch_y)
        
        # Apply MixUp if enabled
        if self.apply_mixup and len(batch_x) > 1:
            batch_x, batch_y = mixup_augmentation(batch_x, batch_y, alpha=0.2)
        
        return batch_x, batch_y
    
    def on_epoch_end(self):
        """Called at the end of each epoch during training"""
        if self.shuffle:
            np.random.shuffle(self.normal_indices)
            np.random.shuffle(self.cancer_indices)

# -------------------------------------------------------
# Attention Mechanisms with Custom Layers
# -------------------------------------------------------

class ChannelAttention(tf.keras.layers.Layer):
    """Custom Channel Attention layer implementation"""
    def __init__(self, ratio=8, **kwargs):
        super(ChannelAttention, self).__init__(**kwargs)
        self.ratio = ratio
        
    def build(self, input_shape):
        channel = input_shape[-1]
        self.gap = GlobalAveragePooling2D()
        self.dense1 = Dense(channel // self.ratio, activation='relu', 
                         kernel_initializer='he_normal', use_bias=False)
        self.dense2 = Dense(channel, activation='sigmoid', 
                         kernel_initializer='he_normal', use_bias=False)
        self.reshape = tf.keras.layers.Reshape((1, 1, channel))
        self.multiply = Multiply()
        
        super(ChannelAttention, self).build(input_shape)
        
    def call(self, inputs):
        gap = self.gap(inputs)
        dense1 = self.dense1(gap)
        dense2 = self.dense2(dense1)
        reshape = self.reshape(dense2)
        
        return self.multiply([inputs, reshape])
    
    def compute_output_shape(self, input_shape):
        return input_shape
    
    def get_config(self):
        config = super(ChannelAttention, self).get_config()
        config.update({
            'ratio': self.ratio
        })
        return config

class ChannelMaxPooling(tf.keras.layers.Layer):
    """Custom layer for max pooling across channels"""
    def __init__(self, **kwargs):
        super(ChannelMaxPooling, self).__init__(**kwargs)
    
    def call(self, inputs):
        return tf.reduce_max(inputs, axis=3, keepdims=True)
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1], input_shape[2], 1)
    
    def get_config(self):
        config = super(ChannelMaxPooling, self).get_config()
        return config

class ChannelAvgPooling(tf.keras.layers.Layer):
    """Custom layer for average pooling across channels"""
    def __init__(self, **kwargs):
        super(ChannelAvgPooling, self).__init__(**kwargs)
    
    def call(self, inputs):
        return tf.reduce_mean(inputs, axis=3, keepdims=True)
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1], input_shape[2], 1)
    
    def get_config(self):
        config = super(ChannelAvgPooling, self).get_config()
        return config

class SpatialAttention(tf.keras.layers.Layer):
    """Custom Spatial Attention layer implementation"""
    def __init__(self, kernel_size=7, **kwargs):
        super(SpatialAttention, self).__init__(**kwargs)
        self.kernel_size = kernel_size
        
    def build(self, input_shape):
        self.channel_max_pool = ChannelMaxPooling()
        self.channel_avg_pool = ChannelAvgPooling()
        self.concat = tf.keras.layers.Concatenate(axis=3)
        self.conv = Conv2D(1, kernel_size=self.kernel_size, padding='same', activation='sigmoid')
        self.multiply = Multiply()
        super(SpatialAttention, self).build(input_shape)
        
    def call(self, inputs):
        # Max pool along channel dimension
        max_pool = self.channel_max_pool(inputs)
        # Average pool along channel dimension
        avg_pool = self.channel_avg_pool(inputs)
        # Concatenate
        concat = self.concat([max_pool, avg_pool])
        # Apply convolution
        attention_map = self.conv(concat)
        # Apply attention
        return self.multiply([inputs, attention_map])
    
    def compute_output_shape(self, input_shape):
        return input_shape
    
    def get_config(self):
        config = super(SpatialAttention, self).get_config()
        config.update({
            'kernel_size': self.kernel_size
        })
        return config

def create_attention_module(x, ratio=8):
    """
    Create a channel attention module using custom layer
    
    Why: Attention mechanisms help the model focus on relevant areas of the image
    and ignore irrelevant parts, which is particularly important for detecting
    subtle cancer features in CT scans.
    """
    return ChannelAttention(ratio=ratio)(x)

def create_spatial_attention_module(x):
    """
    Create a spatial attention module using custom layer
    
    Why: Spatial attention helps the model focus on specific regions
    in the image that are most likely to contain cancer indicators.
    """
    return SpatialAttention(kernel_size=7)(x)

# -------------------------------------------------------
# Enhanced Model Architectures
# -------------------------------------------------------

def create_densenet_model(use_attention=False):
    """Create an enhanced DenseNet121-based model with attention"""
    base_model = DenseNet121(
        weights='imagenet',
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    
    # Freeze base model initially
    base_model.trainable = False
    
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    # Gaussian noise for robustness
    x = tf.keras.layers.GaussianNoise(0.1)(inputs)
    x = base_model(x, training=False)
    
    # Apply attention if enabled
    if use_attention:
        x = create_attention_module(x)
        x = create_spatial_attention_module(x)
    
    x = GlobalAveragePooling2D()(x)
    
    # Enhanced dense layers with stronger regularization
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.0015))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.0015))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    
    # Compile with custom focal loss
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=sigmoid_focal_crossentropy,
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model, base_model

def create_resnet_model(use_attention=False):
    """Create a ResNet50-based model with attention"""
    base_model = ResNet50(
        weights='imagenet',
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    
    # Freeze base model initially
    base_model.trainable = False
    
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    # Gaussian noise for robustness
    x = tf.keras.layers.GaussianNoise(0.1)(inputs)
    x = base_model(x, training=False)
    
    # Apply attention if enabled
    if use_attention:
        x = create_attention_module(x)
        x = create_spatial_attention_module(x)
    
    x = GlobalAveragePooling2D()(x)
    
    # Dense layers with regularization
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    
    # Compile with custom focal loss
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=sigmoid_focal_crossentropy,
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model, base_model

def create_efficientnet_model(use_attention=False):
    """Create an EfficientNetB0-based model with attention"""
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    
    # Freeze base model initially
    base_model.trainable = False
    
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    # Gaussian noise for robustness
    x = tf.keras.layers.GaussianNoise(0.1)(inputs)
    x = base_model(x, training=False)
    
    # Apply attention if enabled
    if use_attention:
        x = create_attention_module(x)
        x = create_spatial_attention_module(x)
    
    x = GlobalAveragePooling2D()(x)
    
    # Dense layers with regularization - using ReLU instead of Swish for compatibility
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    # Output layer
    outputs = Dense(1, activation='sigmoid')(x)
    
    model = Model(inputs, outputs)
    
    # Compile with custom focal loss
    model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=sigmoid_focal_crossentropy,
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model, base_model

def create_ensemble_model(use_attention=False):
    """
    Create an ensemble of multiple models for better performance
    
    Why: Ensemble models combine predictions from different architectures,
    capturing different aspects of the images and generally achieving
    better performance than any single model.
    """
    # Create individual models
    densenet_model, _ = create_densenet_model(use_attention)
    resnet_model, _ = create_resnet_model(use_attention)
    efficientnet_model, _ = create_efficientnet_model(use_attention)
    
    # Common input
    input_layer = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    # Get predictions from each model
    densenet_output = densenet_model(input_layer)
    resnet_output = resnet_model(input_layer)
    efficientnet_output = efficientnet_model(input_layer)
    
    # Combine predictions (weighted average)
    ensemble_output = tf.keras.layers.Average()([
        densenet_output,
        resnet_output,
        efficientnet_output
    ])
    
    # Create ensemble model
    ensemble_model = Model(inputs=input_layer, outputs=ensemble_output)
    
    # Compile model
    ensemble_model.compile(
        optimizer=Adam(learning_rate=0.0001),
        loss=sigmoid_focal_crossentropy,
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return ensemble_model, None

# -------------------------------------------------------
# Create Binary Dataset for Training
# -------------------------------------------------------

def create_binary_dataset(base_dir, mode):
    """
    Create a dataframe of image paths and binary labels (0=normal, 1=cancer)
    
    Args:
        base_dir: Base directory containing class folders
        mode: 'train', 'valid', or 'test'
    
    Returns:
        DataFrame with 'filename' and 'class' columns
    """
    directory = os.path.join(BASE_DIR, mode)
    cancer_classes = [c for c in os.listdir(directory) if c != 'normal']
    all_classes = ['normal'] + cancer_classes
    
    paths = []
    labels = []
    
    for i, class_name in enumerate(all_classes):
        class_dir = os.path.join(directory, class_name)
        if os.path.exists(class_dir):
            files = [os.path.join(class_dir, f) for f in os.listdir(class_dir) 
                    if f.endswith(('.png', '.jpg', '.jpeg'))]
            paths.extend(files)
            # 0 for normal, 1 for any cancer type
            label = 0 if class_name == 'normal' else 1
            labels.extend([label] * len(files))
    
    return pd.DataFrame({'filename': paths, 'class': labels})

# Create dataframes for each split
train_df = create_binary_dataset(BASE_DIR, 'train')
valid_df = create_binary_dataset(BASE_DIR, 'valid')
test_df = create_binary_dataset(BASE_DIR, 'test')

# Display class distribution
print("Class distribution in datasets:")
print(f"Training: {train_df['class'].value_counts()}")
print(f"Validation: {valid_df['class'].value_counts()}")
print(f"Testing: {test_df['class'].value_counts()}")

# -------------------------------------------------------
# Enhanced Training and Evaluation Workflow
# -------------------------------------------------------

# Create data generators
train_datagen = ImageDataGenerator(
    preprocessing_function=custom_preprocessing,
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='reflect'
)

valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Select model architecture based on configuration
if MODEL_ARCHITECTURE == "densenet":
    model, base_model = create_densenet_model(USE_ATTENTION)
elif MODEL_ARCHITECTURE == "resnet":
    model, base_model = create_resnet_model(USE_ATTENTION)
elif MODEL_ARCHITECTURE == "efficientnet":
    model, base_model = create_efficientnet_model(USE_ATTENTION)
elif MODEL_ARCHITECTURE == "ensemble":
    model, base_model = create_ensemble_model(USE_ATTENTION)
else:
    print(f"Unknown architecture: {MODEL_ARCHITECTURE}. Using DenseNet as default.")
    model, base_model = create_densenet_model(USE_ATTENTION)

# Print model summary
model.summary()

# Enhanced callbacks
callbacks = [
    EarlyStopping(
        monitor='val_auc',  # Monitor AUC instead of accuracy for medical tasks
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_auc',
        factor=0.2,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=os.path.join(MODELS_DIR, f'binary_model_{MODEL_ARCHITECTURE}_checkpoint.keras'),
        monitor='val_auc',
        save_best_only=True,
        verbose=1
    ),
    # Add TensorBoard for better visualization
    tf.keras.callbacks.TensorBoard(
        log_dir=os.path.join('logs', MODEL_ARCHITECTURE),
        histogram_freq=1
    )
]

# Use the enhanced generator
train_generator = EnhancedBalancedGenerator(
    train_df, 
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE, IMG_SIZE),
    datagen=train_datagen,
    balanced=True,
    apply_mixup=APPLY_MIXUP
)

valid_generator = EnhancedBalancedGenerator(
    valid_df,
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE, IMG_SIZE),
    datagen=valid_datagen,
    shuffle=False,
    balanced=True
)

test_generator = EnhancedBalancedGenerator(
    test_df,
    batch_size=BATCH_SIZE,
    target_size=(IMG_SIZE, IMG_SIZE),
    datagen=test_datagen,
    shuffle=False,
    balanced=False
)

# Phase 1: Train only the top layers (if not using ensemble)
if base_model is not None:
    print("Phase 1: Training top layers with frozen base model...")
    history_phase1 = model.fit(
        train_generator,
        steps_per_epoch=train_generator.batches_per_epoch,
        validation_data=valid_generator,
        validation_steps=len(valid_generator),
        epochs=10,
        callbacks=callbacks,
        verbose=1
    )

    # Phase 2: Fine-tune the model by unfreezing deeper layers
    print("Phase 2: Fine-tuning the model...")
    
    # Unfreeze the base model but keep early layers frozen
    base_model.trainable = True
    
    # Progressive unfreezing - different strategy based on architecture
    if MODEL_ARCHITECTURE == "densenet":
        # For DenseNet, unfreeze last half of the network
        for layer in base_model.layers[:len(base_model.layers)//2]:
            layer.trainable = False
    elif MODEL_ARCHITECTURE == "resnet":
        # For ResNet, unfreeze last 50 layers
        for layer in base_model.layers[:-50]:
            layer.trainable = False
    elif MODEL_ARCHITECTURE == "efficientnet":
        # For EfficientNet, unfreeze last 30 layers
        for layer in base_model.layers[:-30]:
            layer.trainable = False
    
    # Recompile with lower learning rate
    model.compile(
        optimizer=Adam(learning_rate=0.00001),
        loss=sigmoid_focal_crossentropy,
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    # Continue training
    history_phase2 = model.fit(
        train_generator,
        steps_per_epoch=train_generator.batches_per_epoch,
        validation_data=valid_generator,
        validation_steps=len(valid_generator),
        initial_epoch=len(history_phase1.history['loss']),
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )
    
    # Combine histories
    history_combined = {
        'accuracy': history_phase1.history['accuracy'] + history_phase2.history['accuracy'],
        'val_accuracy': history_phase1.history['val_accuracy'] + history_phase2.history['val_accuracy'],
        'loss': history_phase1.history['loss'] + history_phase2.history['loss'],
        'val_loss': history_phase1.history['val_loss'] + history_phase2.history['val_loss'],
        'auc': history_phase1.history['auc'] + history_phase2.history['auc'],
        'val_auc': history_phase1.history['val_auc'] + history_phase2.history['val_auc'],
        'precision': history_phase1.history['precision'] + history_phase2.history['precision'],
        'val_precision': history_phase1.history['val_precision'] + history_phase2.history['val_precision'],
        'recall': history_phase1.history['recall'] + history_phase2.history['recall'],
        'val_recall': history_phase1.history['val_recall'] + history_phase2.history['val_recall']
    }
else:
    # For ensemble models, train in a single phase
    print("Training ensemble model...")
    history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.batches_per_epoch,
        validation_data=valid_generator,
        validation_steps=len(valid_generator),
        epochs=EPOCHS,
        callbacks=callbacks,
        verbose=1
    )
    
    # For consistent plotting
    history_combined = history.history

# Plot training metrics
plt.figure(figsize=(16, 12))

# Plot accuracy
plt.subplot(2, 2, 1)
plt.plot(history_combined['accuracy'], label='Training Accuracy')
plt.plot(history_combined['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
if base_model is not None:
   plt.axvline(x=len(history_phase1.history['accuracy'])-1, color='r', linestyle='--', label='Fine-tuning start')

# Plot loss
plt.subplot(2, 2, 2)
plt.plot(history_combined['loss'], label='Training Loss')
plt.plot(history_combined['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
if base_model is not None:
   plt.axvline(x=len(history_phase1.history['loss'])-1, color='r', linestyle='--')

# Plot AUC
plt.subplot(2, 2, 3)
plt.plot(history_combined['auc'], label='Training AUC')
plt.plot(history_combined['val_auc'], label='Validation AUC')
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
if base_model is not None:
   plt.axvline(x=len(history_phase1.history['auc'])-1, color='r', linestyle='--')

# Plot Precision-Recall
plt.subplot(2, 2, 4)
plt.plot(history_combined['precision'], label='Training Precision')
plt.plot(history_combined['val_precision'], label='Validation Precision')
plt.plot(history_combined['recall'], label='Training Recall')
plt.plot(history_combined['val_recall'], label='Validation Recall')
plt.title('Precision and Recall')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.legend()
if base_model is not None:
   plt.axvline(x=len(history_phase1.history['precision'])-1, color='r', linestyle='--')

plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, f'training_history_{MODEL_ARCHITECTURE}.png'))
plt.show()

# -------------------------------------------------------
# Enhanced Evaluation on Test Set
# -------------------------------------------------------

# Final evaluation on test data
print("\n=== Final Evaluation on Test Set ===")
test_results = model.evaluate(test_generator, verbose=1)
print(f"Test Loss: {test_results[0]:.4f}")
print(f"Test Accuracy: {test_results[1]:.4f}")
print(f"Test AUC: {test_results[2]:.4f}")
print(f"Test Precision: {test_results[3]:.4f}")
print(f"Test Recall: {test_results[4]:.4f}")

# Get predictions
test_steps = len(test_generator)
test_y_true = []
test_y_pred = []

for i in range(test_steps):
   x_batch, y_batch = test_generator[i]
   test_y_true.extend(y_batch)
   preds = model.predict(x_batch)
   test_y_pred.extend(preds.flatten())

# Convert to numpy arrays
test_y_true = np.array(test_y_true)
test_y_pred = np.array(test_y_pred)

# Convert probabilities to binary predictions using optimal threshold
# Find optimal threshold based on ROC curve for better sensitivity/specificity balance
fpr, tpr, thresholds = roc_curve(test_y_true, test_y_pred)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]
print(f"Optimal threshold from ROC analysis: {optimal_threshold:.4f}")

# Apply optimal threshold
test_y_pred_binary = (test_y_pred > optimal_threshold).astype(int)

# Calculate confusion matrix
cm = confusion_matrix(test_y_true, test_y_pred_binary)

# Display enhanced confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title(f'Confusion Matrix (Threshold: {optimal_threshold:.2f})')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.xticks([0.5, 1.5], ['Normal', 'Cancer'])
plt.yticks([0.5, 1.5], ['Normal', 'Cancer'])
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_DIR, f'confusion_matrix_{MODEL_ARCHITECTURE}.png'))
plt.show()

# Calculate and plot ROC curve with confidence interval
plt.figure(figsize=(10, 8))

# Calculate ROC curve
fpr, tpr, _ = roc_curve(test_y_true, test_y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.plot(fpr, tpr, lw=2, label=f'ROC curve (AUC = {roc_auc:.3f})')

# Plot confidence interval (using bootstrapping)
n_bootstraps = 1000
rng = np.random.RandomState(42)
bootstrapped_aucs = []

for i in range(n_bootstraps):
   # Bootstrap by sampling with replacement
   indices = rng.randint(0, len(test_y_pred), len(test_y_pred))
   if len(np.unique(test_y_true[indices])) < 2:
       # Skip if only one class is present
       continue
   
   # Calculate AUC for this bootstrap sample
   fpr, tpr, _ = roc_curve(test_y_true[indices], test_y_pred[indices])
   bootstrapped_aucs.append(auc(fpr, tpr))

# Calculate 95% confidence interval
bootstrapped_aucs = np.array(bootstrapped_aucs)
auc_95ci = np.percentile(bootstrapped_aucs, [2.5, 97.5])

# Add confidence interval to plot title
plt.title(f'ROC Curve (AUC = {roc_auc:.3f}, 95% CI: {auc_95ci[0]:.3f}-{auc_95ci[1]:.3f})')

# Plot diagonal line (random classifier)
plt.plot([0, 1], [0, 1], 'k--', lw=2)

# Formatting
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1-Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.savefig(os.path.join(PLOTS_DIR, f'roc_curve_{MODEL_ARCHITECTURE}.png'))
plt.show()

# Print detailed classification report
print("\nClassification Report (Using Optimal Threshold):")
print(classification_report(test_y_true, test_y_pred_binary, target_names=['Normal', 'Cancer']))

# -------------------------------------------------------
# Calculate Clinical Metrics
# -------------------------------------------------------

# Calculate clinical metrics
def calculate_clinical_metrics(y_true, y_pred, threshold=0.5):
   """Calculate clinically relevant metrics for model evaluation"""
   # Apply threshold
   y_pred_binary = (y_pred > threshold).astype(int)
   
   # Calculate confusion matrix elements
   tn, fp, fn, tp = confusion_matrix(y_true, y_pred_binary).ravel()
   
   # Calculate metrics
   sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
   specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
   ppv = tp / (tp + fp) if (tp + fp) > 0 else 0  # Positive Predictive Value
   npv = tn / (tn + fn) if (tn + fn) > 0 else 0  # Negative Predictive Value
   
   # F1 score
   f1 = 2 * (ppv * sensitivity) / (ppv + sensitivity) if (ppv + sensitivity) > 0 else 0
   
   # Diagnostic odds ratio (measure of test effectiveness)
   dor = (tp * tn) / (fp * fn) if (fp * fn) > 0 else 0
   
   # Number needed to screen (NNS)
   nns = 1 / (sensitivity * (sum(y_true) / len(y_true))) if (sensitivity * (sum(y_true) / len(y_true))) > 0 else 0
   
   return {
       "Sensitivity (Recall)": sensitivity,
       "Specificity": specificity,
       "Precision (PPV)": ppv,
       "Negative Predictive Value": npv,
       "F1 Score": f1,
       "Diagnostic Odds Ratio": dor,
       "Number Needed to Screen": nns
   }

# Calculate metrics using optimal threshold
clinical_metrics = calculate_clinical_metrics(test_y_true, test_y_pred, threshold=optimal_threshold)

# Print clinical metrics
print("\nClinical Performance Metrics:")
for metric, value in clinical_metrics.items():
   print(f"{metric}: {value:.4f}")

# -------------------------------------------------------
# Enhanced Prediction with Explainability
# -------------------------------------------------------

def predict_cancer_with_explanation(model, image_path, threshold=0.5):
   """
   Predict cancer and provide visual explanation using Grad-CAM
   
   Args:
       model: Loaded TensorFlow/Keras model
       image_path: Path to the image file
       threshold: Classification threshold (default: optimal threshold)
       
   Returns:
       dict: Prediction results and Grad-CAM visualization
   """
   # Load and preprocess the image
   img = Image.open(image_path)
   img = img.resize((IMG_SIZE, IMG_SIZE))
   img = img.convert('RGB')
   img_array = np.array(img) / 255.0
   
   # Make prediction
   x = np.expand_dims(img_array, axis=0)
   prediction = float(model.predict(x)[0][0])
   predicted_class = int(prediction > threshold)
   
   # Class names
   class_names = ['Normal', 'Cancer']
   
   # Create result dictionary
   result = {
       "prediction": class_names[predicted_class],
       "confidence": prediction if predicted_class == 1 else 1 - prediction,
       "cancer_probability": prediction,
       "classification_threshold": threshold
   }
   
   # Generate Grad-CAM visualization
   try:
       # Get the last convolutional layer
       if MODEL_ARCHITECTURE == "densenet":
           last_conv_layer_name = [layer.name for layer in model.layers if 'conv5_block16_concat' in layer.name][0]
       elif MODEL_ARCHITECTURE == "resnet":
           last_conv_layer_name = [layer.name for layer in model.layers if 'conv5_block3_out' in layer.name][0]
       elif MODEL_ARCHITECTURE == "efficientnet":
           last_conv_layer_name = [layer.name for layer in model.layers if 'top_activation' in layer.name][0]
       else:
           # Fallback - find the last conv layer
           conv_layers = [layer.name for layer in model.layers if 'conv' in layer.name.lower() and len(layer.output_shape) == 4]
           last_conv_layer_name = conv_layers[-1] if conv_layers else None
       
       if last_conv_layer_name:
           last_conv_layer = model.get_layer(last_conv_layer_name)
           
           # Create a model that maps the input image to the activations of the last conv layer
           grad_model = tf.keras.models.Model(
               [model.inputs], 
               [last_conv_layer.output, model.output]
           )
           
           # Compute gradient of the prediction with respect to the output of the last conv layer
           with tf.GradientTape() as tape:
               last_conv_layer_output, predictions = grad_model(x)
               loss = predictions[:, 0]  # For binary classification
           
           # Gradient of the output neuron with respect to the output feature map
           grads = tape.gradient(loss, last_conv_layer_output)
           
           # Vector of mean intensity of gradient over feature map
           pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
           
           # Weight the channels by the gradient importance
           last_conv_layer_output = last_conv_layer_output[0]
           heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
           heatmap = tf.squeeze(heatmap)
           
           # Normalize the heatmap
           heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
           heatmap = heatmap.numpy()
           
           # Resize heatmap to original image size
           import cv2
           heatmap_resized = cv2.resize(heatmap, (img_array.shape[1], img_array.shape[0]))
           
           # Create a colored heatmap
           heatmap_rgb = np.uint8(255 * plt.cm.jet(heatmap_resized)[:, :, :3])
           
           # Superimpose the heatmap on original image
           superimposed_img = np.uint8(0.6 * img_array * 255 + 0.4 * heatmap_rgb)
           
           # Create and save the visualization
           fig, ax = plt.subplots(1, 3, figsize=(15, 5))
           ax[0].imshow(img_array)
           ax[0].set_title('Original Image')
           ax[0].axis('off')
           
           ax[1].imshow(heatmap_resized, cmap='jet')
           ax[1].set_title('Heatmap')
           ax[1].axis('off')
           
           ax[2].imshow(superimposed_img)
           ax[2].set_title(f'Prediction: {result["prediction"]} ({result["confidence"]:.2%})')
           ax[2].axis('off')
           
           plt.tight_layout()
           explanation_path = f"explanation_{os.path.basename(image_path).split('.')[0]}.png"
           plt.savefig(explanation_path)
           plt.close()
           
           # Add explanation path to result
           result["explanation_path"] = explanation_path
   except Exception as e:
       print(f"Error generating Grad-CAM: {e}")
       result["explanation_error"] = str(e)
   
   return result

# -------------------------------------------------------
# Save models in multiple formats with versioning
# -------------------------------------------------------

# Create timestamp for version tracking
import datetime
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

# Save the model in Keras format
model_keras_path = os.path.join(MODELS_DIR, f'chest_ct_binary_classifier_{MODEL_ARCHITECTURE}_{timestamp}.keras')
model.save(model_keras_path)
print(f"Model saved in Keras format: {model_keras_path}")

# Save the model in TensorFlow SavedModel format
model_tf_path = os.path.join(MODELS_DIR, f'chest_ct_binary_classifier_{MODEL_ARCHITECTURE}_tf_{timestamp}')
tf.saved_model.save(model, model_tf_path)
print(f"Model saved in TensorFlow SavedModel format: {model_tf_path}")

# Save in TFLite format with optimization for edge devices
converter = tf.lite.TFLiteConverter.from_keras_model(model)
# Enable optimizations
converter.optimizations = [tf.lite.Optimize.DEFAULT]
# Quantize model for smaller size and faster inference
tflite_model = converter.convert()
tflite_path = os.path.join(MODELS_DIR, f'chest_ct_binary_classifier_{MODEL_ARCHITECTURE}_{timestamp}.tflite')
with open(tflite_path, 'wb') as f:
   f.write(tflite_model)
print(f"Model saved in optimized TFLite format: {tflite_path}")

# Save as h5 for compatibility
model_h5_path = os.path.join(MODELS_DIR, f'chest_ct_binary_classifier_{MODEL_ARCHITECTURE}_{timestamp}.h5')
model.save(model_h5_path)
print(f"Model saved in h5 format: {model_h5_path}")

# -------------------------------------------------------
# Summary and Model Comparison
# -------------------------------------------------------

print("\n=== Enhanced Binary Cancer Detection Model Summary ===")
print(f"Architecture: {MODEL_ARCHITECTURE}")
print(f"Attention Mechanisms: {'Enabled' if USE_ATTENTION else 'Disabled'}")
print(f"MixUp Augmentation: {'Enabled' if APPLY_MIXUP else 'Disabled'}")
print(f"Input Image Size: {IMG_SIZE}x{IMG_SIZE}")
print(f"Training Images: {len(train_df)}")
print(f"Validation Images: {len(valid_df)}")
print(f"Test Images: {len(test_df)}")
print(f"Training Class Balance: {dict(train_df['class'].value_counts())}")
print(f"Final Test Accuracy: {test_results[1]:.4f}")
print(f"Final Test AUC: {test_results[2]:.4f}")
print(f"Optimal Classification Threshold: {optimal_threshold:.4f}")

# Save current metrics as new baseline
current_metrics = {
   'architecture': MODEL_ARCHITECTURE,
   'attention': USE_ATTENTION,
   'mixup': APPLY_MIXUP,
   'accuracy': float(test_results[1]),
   'auc': float(test_results[2]),
   'precision': float(test_results[3]),
   'recall': float(test_results[4]),
   'optimal_threshold': float(optimal_threshold),
   'timestamp': timestamp
}

import json
with open(os.path.join(PLOTS_DIR, f'metrics_{MODEL_ARCHITECTURE}_{timestamp}.json'), 'w') as f:
   json.dump(current_metrics, f)

print("\nModel saved in multiple formats for deployment.")

print("\nNext steps could include:")
print("1. Implementing 3D CNN variants for volumetric CT analysis")
print("2. Adding Vision Transformer modules for better feature extraction")
print("3. Creating a model ensemble with different architectures and input sizes")
print("4. Implementing test-time augmentation for more robust predictions")
print("5. Deploying as a web service with Grad-CAM visualization for explainability")
print("6. Exploring self-supervised pre-training on unlabeled CT data")
print("7. Implementing uncertainty estimation techniques")
# Out:
# 2025-04-25 02:23:24.196744: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745547804.389731      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745547804.446716      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class distribution in datasets:
# Training: class
# 1    465
# 0    148
# Name: count, dtype: int64
# Validation: class
# 1    59
# 0    13
# Name: count, dtype: int64
# Testing: class
# 1    261
# 0     54
# Name: count, dtype: int64
# I0000 00:00:1745547817.482814      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise (GaussianNoise)       │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ densenet121 (Functional)             │ (None, 8, 8, 1024)          │       7,037,504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ channel_attention (ChannelAttention) │ (None, 8, 8, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_attention (SpatialAttention) │ (None, 8, 8, 1024)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1024)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,696,961 (29.36 MB)
#  Trainable params: 657,921 (2.51 MB)
#  Non-trainable params: 7,039,040 (26.85 MB)
# Phase 1: Training top layers with frozen base model...
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745547851.077304      58 service.cc:148] XLA service 0x7ed5b00960b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745547851.078443      58 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745547854.200918      58 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745547866.089872      58 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 74/75 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.3744 - auc: 0.4960 - loss: 1.6623 - precision: 0.6024 - recall: 0.4853
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_auc improved from inf to 0.49833, saving model to models/binary_model_densenet_checkpoint.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 110s 872ms/step - accuracy: 0.3749 - auc: 0.4957 - loss: 1.6606 - precision: 0.6024 - recall: 0.4853 - val_accuracy: 0.5000 - val_auc: 0.4983 - val_loss: 1.3450 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/10
# /usr/lib/python3.11/contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_auc` which is not available. Available metrics are: accuracy,auc,loss,precision,recall
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_auc` which is not available. Available metrics are: accuracy,auc,loss,precision,recall,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_auc available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/10
# 74/75 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.3923 - auc: 0.4977 - loss: 1.3973 - precision: 0.6269 - recall: 0.4985
# Epoch 3: val_auc improved from 0.49833 to 0.26138, saving model to models/binary_model_densenet_checkpoint.keras
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 53s 672ms/step - accuracy: 0.3927 - auc: 0.4979 - loss: 1.3954 - precision: 0.6270 - recall: 0.4985 - val_accuracy: 0.5000 - val_auc: 0.2614 - val_loss: 1.1345 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 4/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/10
# 74/75 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.3935 - auc: 0.5223 - loss: 1.1766 - precision: 0.6225 - recall: 0.4704
# Epoch 5: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 635ms/step - accuracy: 0.3936 - auc: 0.5221 - loss: 1.1756 - precision: 0.6221 - recall: 0.4697 - val_accuracy: 0.5000 - val_auc: 0.4865 - val_loss: 0.9850 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 6/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/10
# 74/75 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.4038 - auc: 0.5195 - loss: 1.0341 - precision: 0.6575 - recall: 0.4544
# Epoch 7: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 50s 628ms/step - accuracy: 0.4034 - auc: 0.5191 - loss: 1.0338 - precision: 0.6565 - recall: 0.4535 - val_accuracy: 0.5000 - val_auc: 0.5603 - val_loss: 0.8879 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 8/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 9/10
# 74/75 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.3895 - auc: 0.5012 - loss: 0.9418 - precision: 0.6188 - recall: 0.4285
# Epoch 9: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 50s 625ms/step - accuracy: 0.3894 - auc: 0.5006 - loss: 0.9415 - precision: 0.6181 - recall: 0.4280 - val_accuracy: 0.5000 - val_auc: 0.4480 - val_loss: 0.8394 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 10/10
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 7.
# Phase 2: Fine-tuning the model...
# Epoch 11/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.3852 - auc: 0.4802 - loss: 0.9629 - precision: 0.6149 - recall: 0.3975
# Epoch 11: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 167s 810ms/step - accuracy: 0.3851 - auc: 0.4802 - loss: 0.9630 - precision: 0.6149 - recall: 0.3978 - val_accuracy: 0.5000 - val_auc: 0.6498 - val_loss: 1.1182 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 12/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 13/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.4339 - auc: 0.5539 - loss: 0.9313 - precision: 0.6470 - recall: 0.4762
# Epoch 13: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 643ms/step - accuracy: 0.4338 - auc: 0.5538 - loss: 0.9313 - precision: 0.6471 - recall: 0.4761 - val_accuracy: 0.5000 - val_auc: 0.3360 - val_loss: 1.1520 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 14/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 15/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.3737 - auc: 0.4822 - loss: 0.9394 - precision: 0.6294 - recall: 0.4319
# Epoch 15: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 647ms/step - accuracy: 0.3737 - auc: 0.4820 - loss: 0.9395 - precision: 0.6293 - recall: 0.4319 - val_accuracy: 0.5000 - val_auc: 0.7858 - val_loss: 1.7377 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 16/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 17/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.3917 - auc: 0.5182 - loss: 0.9295 - precision: 0.6360 - recall: 0.4602
# Epoch 17: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 642ms/step - accuracy: 0.3915 - auc: 0.5180 - loss: 0.9295 - precision: 0.6356 - recall: 0.4598 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 2.5691 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 18/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 19/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.4143 - auc: 0.5126 - loss: 0.9121 - precision: 0.6168 - recall: 0.4579
# Epoch 19: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 641ms/step - accuracy: 0.4140 - auc: 0.5123 - loss: 0.9122 - precision: 0.6167 - recall: 0.4576 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 3.1785 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 20/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 21/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.3893 - auc: 0.4959 - loss: 0.9226 - precision: 0.6280 - recall: 0.4451
# Epoch 21: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 641ms/step - accuracy: 0.3895 - auc: 0.4959 - loss: 0.9227 - precision: 0.6279 - recall: 0.4452 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 3.6918 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 22/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 23/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.3544 - auc: 0.4955 - loss: 0.9191 - precision: 0.5881 - recall: 0.4220
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
#
# Epoch 23: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 638ms/step - accuracy: 0.3546 - auc: 0.4955 - loss: 0.9191 - precision: 0.5882 - recall: 0.4221 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 3.6382 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 24/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 2.0000e-06
# Epoch 25/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.4066 - auc: 0.4848 - loss: 0.9102 - precision: 0.5830 - recall: 0.3758
# Epoch 25: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 643ms/step - accuracy: 0.4066 - auc: 0.4852 - loss: 0.9101 - precision: 0.5834 - recall: 0.3762 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 3.7771 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 2.0000e-06
# Epoch 26/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 2.0000e-06
# Epoch 27/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.4241 - auc: 0.5226 - loss: 0.8884 - precision: 0.6503 - recall: 0.4534
# Epoch 27: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 649ms/step - accuracy: 0.4239 - auc: 0.5226 - loss: 0.8885 - precision: 0.6502 - recall: 0.4534 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 3.8736 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 2.0000e-06
# Epoch 28/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 2.0000e-06
# Epoch 29/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.3957 - auc: 0.4708 - loss: 0.9178 - precision: 0.6091 - recall: 0.4312
# Epoch 29: val_auc did not improve from 0.26138
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 51s 641ms/step - accuracy: 0.3957 - auc: 0.4710 - loss: 0.9176 - precision: 0.6092 - recall: 0.4312 - val_accuracy: 0.5000 - val_auc: 0.5000 - val_loss: 3.9660 - val_precision: 0.5000 - val_recall: 1.0000 - learning_rate: 2.0000e-06
# Epoch 30/30
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.0000e+00 - auc: 0.0000e+00 - loss: 0.0000e+00 - precision: 0.0000e+00 - recall: 0.0000e+00 - learning_rate: 2.0000e-06
# Restoring model weights from the end of the best epoch: 15.
# === Final Evaluation on Test Set ===
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - accuracy: 0.5518 - auc: 0.6839 - loss: 2.4128 - precision: 0.5518 - recall: 0.8500
# Test Loss: 1.4039
# Test Accuracy: 0.8224
# Test AUC: 0.8039
# Test Precision: 0.8224
# Test Recall: 1.0000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Optimal threshold from ROC analysis: 0.9961
# Classification Report (Using Optimal Threshold):
#               precision    recall  f1-score   support
#
#       Normal       0.73      0.76      0.75        54
#       Cancer       0.95      0.94      0.94       250
#
#     accuracy                           0.91       304
#    macro avg       0.84      0.85      0.84       304
# weighted avg       0.91      0.91      0.91       304
#
#
# Clinical Performance Metrics:
# Sensitivity (Recall): 0.9400
# Specificity: 0.7593
# Precision (PPV): 0.9476
# Negative Predictive Value: 0.7321
# F1 Score: 0.9438
# Diagnostic Odds Ratio: 49.4103
# Number Needed to Screen: 1.2936
# Model saved in Keras format: models/chest_ct_binary_classifier_densenet_20250425_024058.keras
# Model saved in TensorFlow SavedModel format: models/chest_ct_binary_classifier_densenet_tf_20250425_024058
# Saved artifact at '/tmp/tmpp69p8bzx'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name='keras_tensor_427')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139459757697424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757699344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757698000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757698384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757697616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757698768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757699920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757697808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757696656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757701072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757702032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757702416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757701840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757700880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756622096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756623632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756623056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756623440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756622288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756624592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756625552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756623824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756624208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756625360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756626896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756628240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756628432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756628048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756627280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756628816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756630160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756630352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756629968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756629200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756630736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756632080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756632272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756631888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756631120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756632656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756634000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756634192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756633808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756633040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756631504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756636112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756636304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756635920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756626512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756634960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756636688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757694160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756637648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459760291280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459756635536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757999312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757998160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757999120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757999504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757999888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758001232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758001424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758001040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758000272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758001808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758003152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758003344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758002960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758002192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758003728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758005072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758005264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758004880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758004112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758005648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758006992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758007184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758006800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758006032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758007568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758008912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758009104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758008720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758007952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758009488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758010832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758011024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758010640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758009872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758011408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758012752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758012944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758011792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758013328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758013712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736109712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459757998736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459758012176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736109904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736111248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736111440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736111056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736110288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736111824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736113168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736113360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736112976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736112208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736113744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736115088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736115280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736114896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736114128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736115664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736117008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736117200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736116816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736116048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736117584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736118928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736119120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736118736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736117968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736119504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736120848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736121040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736120656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736119888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736121424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736122768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736122960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736122576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736121808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736123344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736124688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736124880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736124496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736123728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736683728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736682576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736683536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736683920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736684304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736685648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736685840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736685456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736684688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736686224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736687568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736687760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736687376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736686608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736688144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736689488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736689680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736689296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736688528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736690064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736691408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736691600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736691216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736690448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736691984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736693328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736693520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736693136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736692368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736693904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736695248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736695440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736695056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736694288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736695824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736697168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736697360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736696976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736696208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736697744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736698128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614982800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736683152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459736696592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614982992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614984336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614984528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614984144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614983376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614984912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614986256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614986448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614986064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614985296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614986832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614988176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614988368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614987984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614987216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614988752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614990096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614990288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614989904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614989136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614990672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614992016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614992208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614991824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614991056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614992592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614993936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614994128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614993744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614992976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614994512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614995856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614996048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614995664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614994896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614996432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614997776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614997968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614997584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614996816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459614995280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615556432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615555664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615556624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615555856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615557392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615558736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615558928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615558544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615557776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615559312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615560656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615560848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615560464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615559696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615561232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615562576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615562768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615562384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615561616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615563152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615564496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615564688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615564304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615563536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615565072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615566416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615566608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615566224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615565456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615566992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615568528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615568144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615567376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615568912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615570064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615569296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615571216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602596496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615557008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459615569680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602596688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602598032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602598224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602597840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602597072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602598608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602599952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602600144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602599760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602598992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602600528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602601872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602602064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602601680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602600912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602602448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602603792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602603984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602603600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602602832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602604368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602605712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602605904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602605520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602604752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602606288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602607632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602607824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602607440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602606672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602608208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602609552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602609744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602609360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602608592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602610128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602611472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602611664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602611280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602610512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459602608976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603202896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603202128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603203088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603202320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603203856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603205200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603205392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603205008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603204240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603205776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603207120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603207312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603206928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603206160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603207696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603209040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603209232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603208848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603208080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603209616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603210960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603211152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603210768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603210000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603211536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603212880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603213072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603212688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603211920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603213456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603214800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603214992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603214608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603213840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603215376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603216720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603216912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603216528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603215760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603217296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603217680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313304208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603203472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459603216144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313304400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313305744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313305936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313305552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313304784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313306320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313307664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313307856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313307472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313306704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313308240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313309584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313309776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313309392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313308624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313310160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313311504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313311696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313311312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313310544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313312080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313313424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313313616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313313232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313312464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313314000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313315344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313315536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313315152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313315920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313317264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313317456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313317072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313316304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313317840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313319376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313318992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313318224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313316688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313861840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313860688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313861648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313862032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313862416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313863760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313863952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313863568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313862800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313864336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313865680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313865872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313865488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313864720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313866256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313867600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313867792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313867408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313866640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313868176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313869520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313869712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313869328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313868560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313870096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313871440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313871632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313871248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313870480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313872016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313873360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313873552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313873168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313872400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313873936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313875280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313875472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313875088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313874320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313875856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313876240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470314640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313861264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139459313874704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470314832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470316176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470316368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470315984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470315216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470316752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470318096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470318288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470317904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470317136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470318672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470320016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470320208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470319824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470319056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470320592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470321936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470322128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470321744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470320976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470322512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470323856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470324048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470323664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470322896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470324432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470325776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470325968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470325584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470324816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470326352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470327696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470327888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470327504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470326736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470328272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470329616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470329808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470329424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470328656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470327120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470888656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470887504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470888464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470888848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470890576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470890768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470890384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470889616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470891152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470892496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470892688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470892304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470891536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470893072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470894416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470894608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470894224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470893456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470894992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470896336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470896528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470896144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470895376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470896912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470898256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470898448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470898064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470897296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470898832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470900176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470900368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470899984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470899216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470900752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470902096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470902288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470901904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470901136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470902672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470903056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180989584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470888080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458470901520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180989776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180991120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180991312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180990928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180990160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180991696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180993040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180993232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180992848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180992080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180993616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180994960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180995152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180994768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180994000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180995536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180996880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180997072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180996688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180995920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180997456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180998800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180998992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180998608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180997840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180999376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181000720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181000912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181000528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458180999760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181001296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181002640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181002832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181002448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181001680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181003216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181004560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181004752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181004368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181003600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181002064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181514448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181513680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181514256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181514640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181515024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181516368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181516560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181516176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181515408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181516944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181518288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181518480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181518096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181517328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181518864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181520208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181520400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181520016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181519248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181520784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181522128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181522320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181521936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181521168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181522704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181524048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181524240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181523856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181523088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181524624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181525968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181526160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181525776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181525008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181526544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181527888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181528080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181527696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181526928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457388544080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457388545232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457388548112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457388550224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139458181527312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838728592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838728208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838727440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838728784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838728016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838731280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838731664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838730896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838730704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838731472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838729360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139457838733968: TensorSpec(shape=(), dtype=tf.resource, name=None)
# W0000 00:00:1745548950.640788      19 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1745548950.640825      19 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1745548950.976237      19 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# Model saved in optimized TFLite format: models/chest_ct_binary_classifier_densenet_20250425_024058.tflite
# Model saved in h5 format: models/chest_ct_binary_classifier_densenet_20250425_024058.h5
#
# === Enhanced Binary Cancer Detection Model Summary ===
# Architecture: densenet
# Attention Mechanisms: Enabled
# MixUp Augmentation: Enabled
# Input Image Size: 256x256
# Training Images: 613
# Validation Images: 72
# Test Images: 315
# Training Class Balance: {1: 465, 0: 148}
# Final Test Accuracy: 0.8224
# Final Test AUC: 0.8039
# Optimal Classification Threshold: 0.9961
#
# Model saved in multiple formats for deployment.
#
# Next steps could include:
# 1. Implementing 3D CNN variants for volumetric CT analysis
# 2. Adding Vision Transformer modules for better feature extraction
# 3. Creating a model ensemble with different architectures and input sizes
# 4. Implementing test-time augmentation for more robust predictions
# 5. Deploying as a web service with Grad-CAM visualization for explainability
# 6. Exploring self-supervised pre-training on unlabeled CT data
# 7. Implementing uncertainty estimation techniques
